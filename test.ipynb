# %%
class minHeap:
    def __init__(self, maxsize):
        self.maxsize = maxsize
        self.size = 0
        self.heap = [0] * (maxsize+1)
        self.heap[0] = -float(inf)
        self.top = 1

    def buildHeap(self):
        for i in range(self.size//2, 0, -1): # start at bottom
            self.heapify(i)

    def heapify(self, i):
        if not self.isLeaf(i):
            if (self.heap[i] > self.heap[self.left(i)] or self.heap[i] > self.heap[self.right(i)]):
                if (self.heap[self.left[i]] < self.heap[self.right[i]]:
                    swap_nodes(i, self.left(i))
                    self.heapify(self.left(i))
                else:
                    swap_nodes(i, self.right[i])
                    self.heapify(self.right(i))

    def insert(self, val): 
        if self.size >= self.maxsize : 
            return
        self.size += 1
        insert at the end
        self.heap[self.size] = val 
        current = self.size 
        while self.heap[current] < self.heap[self.parent(current)]: 
            self.swap(current, self.parent(current)) 
            current = self.parent(current) 

    def getMin(self):   
        min_value = self.Heap[self.top] 
        self.heap[self.top] = self.heap[self.size] 
        self.size -= 1
        self.heapify(self.top) 
        return min_value 

    def isLeaf(self, i): 
        if i >= (self.size//2) and i <= self.size: 
            return True
        return False
    
    def parent(self,i):
        return i//2
    
    def left_child(self,i):
        return 2*i

    def right_child(self,i):
        return 2*i+1
        
    def isLeaf(self,i):
        if i >= self.size
        
    def swap_nodes(self,i,j):
        self.heap[i], self.heap[j] = self.heap[j], self.heap[i]
