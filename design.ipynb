# %%
import collections
from collections import deque
from collections import defaultdict
import heapq
import random

class Solution(object):
    def countShips(self, sea, topRight, bottomLeft):
    
        result = 0
        x1, y1 = topRight[0], topRight[1]
        x2, y2 = bottomLeft[0], bottomLeft[1]
        x, y = (x1+x2)//2, (y1+y2)//2
        if x1 > x2 or y1 > y2:
            return 0
        if not not sea.hasShips(topRight, bottomLeft): 
            return 0
        if x1 == x2 and y1 == y2:
            return 1
        result += self.countShips(sea, Point(x,y2),  Point(x1,y+1))
        result += self.countShips(sea, Point(x2,y2), Point(x+1,y+1))
        result += self.countShips(sea, Point(x,y),   Point(x1,y1))
        result += self.countShips(sea, Point(x2,y),  Point(x+1,y1))    
        return result
        
        def dfs(x1, y1, x2, y2):
            if x1 > x2 or y1 > y2:
                return 0
            if not sea.hasShips(x1, y1, x2, y2):
                return 0
            if x1 == x2 and y1 == y2:
                return 1
            x, y = (x1+x2)//2, (y1+y2)//2
            #r1 = dfs(x1,   y1,  x,  y)
            #r2 = dfs(x1,  y+1,  x, y2)
            #r3 = dfs(x+1,  y1, x2,  y)
            #r4 = dfs(x+1, y+1, x2, y2)            
            #return r1+r2+r3+r4
            result = 0
            result += dfs(x1,   y1,  x,  y)
            result += dfs(x1,  y+1,  x, y2)
            result += dfs(x+1,  y1, x2,  y)
            result += dfs(x+1, y+1, x2, y2)            
            return result     
        return dfs(bottomLeft[0], topRight[0], bottomLeft[1], topRight[1])

# %%
class Solution:
    def candyCrush(self, board):

        ny, nx = len(board), len(board[0])
        dirs = [[0, 1], [0, -1], [1,0], [-1,0]]

        def search_for_matches(board):
            # begin dfs
            cache = [[0]*nx for j in range(0, ny)]
            n_crushed = 0
            for j in range(0, ny):
                for i in range(0, nx):
                    if board[j][i] > 0:
                        n_consec = dfs_calc_depth(board, cache, j, i, 1, board[j][i])
                        if n_consec >= 3:
                            n_crushed += 1
                            dfs_crush(board, cache, j, i, board[j][i])
            if n_crushed > 0:
                gravity(board)
            else: 
                return
        
        def dfs_crush(board,j,i,color):
            for dir in dirs:
                j_new, i_new = j+dir[0], i+dir[1]
                if i_new > 0 and i_new < nx and j_new > 0 and j_new < ny and board[j_new][i_new] == color:  
                    board[j_new][i_new] = 0
                    dfs_crush(board,j_new,i_new,color)
                    
        def dfs_calc_depth(board, cache, j, i, depth, color):
            for dir in dirs:
                j_new, i_new = j+dir[0], i+dir[1]
                if i_new > 0 and i_new < nx and j_new > 0 and j_new < ny and cache[j_new][i_new] != 1 and board[j_new][i_new] == color:  
                    cache[j_new][i_new] = 1
                    depth = dfs_calc_depth(board, j_new, i_new, depth+1, color)
                            
        def gravity:
            modified = True
            for i in range(0, nx):
                for j in range(ny-1, -1, -1):
                    if board[j][i] == 0:
                        modified = True
                        board[j:1][i] = board[j+1:][i]
                        board[0][i] = 0
            if modified:
                search_for_matches(board)
            else:
                return
            
        search_for_matches(board)
            
        
    def candyCrush(self, board: List[List[int]]) -> List[List[int]]:
        ny, nx = len(board), len(board[0])
        # board[j][i]
        # [0][0] is upper left
    
        def dfs_count(j,i,count):            
            if j > 0    and board[j][i] == board[j-1][i]:
                if cache[j-1][i] == 0:
                    count = dfs_count(j-1, i  , count+1)
            if j < ny-1 and board[j][i] == board[j-1][i]:
                if cache[j+1][i] == 0:
                    count = dfs_count(j+1, i  , count+1)
            if i > 0    and board[j][i] == board[j-1][i]:
                if cache[j][i-1] == 0:
                    count = dfs_count(j  , i-1, count+1)
            if i < nx-1 and board[j][i] == board[j-1][i]:
                if cache[j][i+1] == 0:
                    count = dfs_count(j  , i+1, count+1)

        def dfs_crush(j,i, old_board):   
            board[j][i] = 0
            if j > 0    and board[j][i] == old_board:
                dfs_crush(j-1, i  , board[j][i])
            if j < ny-1 and board[j][i] == old_board:
                dfs_crush(j+1, i  , board[j][i])
            if i > 0    and board[j][i] == old_board:
                dfs_crush(j  , i-1, board[j][i])
            if i < nx-1 and board[j][i] == old_board:
                dfs_crush(j  , i+1, board[j][i])
                                    
        def crush(board):
            cache = [[0]*ny for x in range(0, nx)]
            modified = False
            for i in range(0, nx):
                for j in range(ny-1, -1):
                    if cache[j][i] == 0 and board[j][i] > 0: # not checked yet
                        count = 0
                        cache[j][i] = 1
                        count = self.dfs_count(j,i,count)
                        if count >= 3:
                            modified = True
                            self.dfs_crush(j,i, board[j][i])
            if modified:
                self.gravity(board)
            else:
                return
            
        def gravity(board):
            modified = False
            for i in range(0, nx):
                for j in range(ny-1, -1):
                    if board[j][i] == 0:
                        modified = True
                        board[j:1][i] = board[j+1:][i]
                        board[0][i] = 0
            if modified:
                self.candyCrush(board)
            else:
                return 
                

        
        
        
board = [[110,5,112,113,114],[210,211,5,213,214],[310,311,3,313,314],[410,411,412,5,414],[5,1,512,3,3],[610,4,1,613,614],[710,1,2,713,714],[810,1,2,1,1],[1,1,2,2,2],[4,1,4,4,1014]]

# %%
class lruCache:

    def __init__(self, capacity: int):
        self.capacity = capacity
        self.cache = {}
        #self.cache = collections.defaultdict(int, maxsize=capacity)
        self.next, self.prev = {}, {}
        self.head, self.tail = 'not_recent', 'recent'
        self.connect(self.head, self.tail)
        # head not recent -> next -> tail recent
        
    def connect(self, a, b):
        self.next[a], self.prev[b] = b, a

    def delete(self, key):
        self.connect(self.prev[key], self.next[key])        
        del self.cache[key]
        #del self.before[key], self.next[key], self.cache[key]
                
    def append(self, key, value):
        self.cache[key] = value
        self.connect(self.prev[self.tail], key)
        self.connect(key, self.tail)
        if len(self.cache) > self.capacity:
            self.delete(self.next[self.head])
            
    def get(self, key):
        if key not in self.cache:
            return -1
        value = self.cache[key]
        self.delete(key)
        self.append(key, value)
        return value

    
    def put(self, key, value):
        if key in self.cache:
            self.delete(key)
        self.append(key, value)
        
        
        
        
lRUCache = lruCache(2);

lRUCache.put(1, 1) #; // cache is {1=1}
lRUCache.put(2, 2)#; // cache is {1=1, 2=2}
lRUCache.get(1)#;    // return 1
lRUCache.put(3, 3)#; // LRU key was 2, evicts key 2, cache is {1=1, 3=3}
lRUCache.get(2)#;    // returns -1 (not found)
lRUCache.put(4, 4)#; // LRU key was 1, evicts key 1, cache is {4=4, 3=3}
lRUCache.get(1)#;    // return -1 (not found)
lRUCache.get(3)#;    // return 3
lRUCache.get(4)#;    // return 4

# %%
class MinStack:
    def __init__(self):
        self.stack = []
        
    def push(self, x):
        new_min = min(self.getMin(), x)
        self.stack.append((x, new_min)) 
           
    def pop(self):
        self.stack.pop()

    def top(self):
        if self.stack:
            return self.stack[-1][0]
        
    def getMin(self):
        if self.stack:
            return self.stack[-1][1]
        else:
            return float('inf')
        
        
min_stack = MinStack()
min_stack.push(-2)
min_stack.push(0)
min_stack.push(-3)
min_stack.getMin()
min_stack.pop()
min_stack.top()
min_stack.getMin()
print(min_stack)
#print(temp1.maximumProduct(nums))
#print(nums)

# %%
class UndergroudSystem:
    def __init__(self):
        print('init')
        #self.stationNameList = []
        #self.idList = []
        self.checkInDict = collections.defaultdict(list)
        self.travelTimes = collections.defaultdict(list)
        
    def checkIn(self, id, stationName, t):
        '''check into station at time t, can only be checked into one station at a time'''
        if id in self.checkInDict:
            print('ERROR - user cannot check in to to places at once')
        else:
            self.checkInDict[id] = [t, stationName]
        
    def checkOut(self, id, stationName, t):
        '''check out of station'''
        if id not in self.checkInDict:
            print('ERROR - user cannot check out before checking in')
        else: 
            tStart, startStation = self.checkInDict[id]
            deltaTime = t - tStart
            stationPair = startStation+'-'+stationName
            print(stationPair)
            self.travelTimes[stationPair].append(deltaTime)
            #self.travelTimes[(start_station, stationName)].append(deltaTime)
            del self.checkInDict[id]        

    def getAverageTime(self, startStation, endStation):
        '''return avg time from point to point'''
        print('getAverageTime')
        stationPair = startStation+'-'+endStation
        print(stationPair)
        if stationPair not in self.travelTimes:
            print('ERROR - station pair not present')
        else:
            times = self.travelTimes[stationPair]
            avgTime = float(sum(times)/len(times))
            print(stationPair, avgTime)
            return avgTime

# %%
class MinStack:
    def __init__(self):
        self.stack = []
        
    def push(self, x):
        new_min = min(self.getMin(), x)
        self.stack.append((x, new_min)) 
           
    def pop(self):
        self.stack.pop()

    def top(self):
        if self.stack:
            return self.stack[-1][0]
        
    def getMin(self):
        if self.stack:
            return self.stack[-1][1]
        else:
            return float('inf')

# %%
    def __init__(self, nums):
        self.cache = collections.defaultdict(list)
        for index,n in enumerate(nums):
            self.cache[n].append(index)
        #print(self.cache)
        
    def pick(self, target):
        #print(self.cache)
        if len(self.cache[target]) == 1:
            return self.cache[target][0]
        else:
            #rand_int = random.randrange(len_temp)
            #return self.cache[target][rand_int]
            return random.choice(self.cache[target])
