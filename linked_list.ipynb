# %%
class ListNode(object):
    #def __init__(self, x, nxt=None, random=None):
    #def __init__(self, x, next=None, prev=None, child=None, random=None):
    def __init__(self, val=0, next=None):
        #self.value = x
        self.val = val
        self.next = next
        #self.prev = prev
        #self.child = child
        #self.random = random
    
class Solution:

    def copyRandomList(self, head):
        if not head:
            return 
        cache = {}
        #cache = collections.defaultdict(lambda: Node(0, None, None))
        while current:
            cache[current] = Node(current.val)
            current = current.next
        current = head
        while current:
            if current.next:
                cache[current].next   = cache[current.next]
            if current.random:
                cache[current].random = cache[current.random]
            current = current.next
        return current[head]
    
    def flatten(self, head):
        if not head:
            return
        dummy = Node(0,None,head,None)     
        stack = []
        stack.append(head)
        prev = dummy        
        while stack:
            current = stack.pop()
            current.prev, prev.next = prev, current
            if current.next:
                stack.append(current.next)
                current.next = None
            if current.child:
                stack.append(current.child)
                current.child = None
            prev = current        
        dummy.next.prev = None
        return dummy.next                
        
    def addTwoNumbers(self, l1, l2): # start from rev ll
        dummy = current = ListNode(0)
        carry = 0
        while l1 or l2 or carry:
            if l1:
                carry += l1.val
                l1 = l1.next
            if l2:
                carry += l2.val
                l2 = l2.next
            current.next = ListNode(carry%10)
            current = current.next
            carry //= 10
        return dummy.next
    
    def addTwoNumbers(self, l1, l2):
        stack1, stack2 = [], []
        while l1:
            stack1.append(l1.val)
            l1 = l1.next
        while l2:
            stack2.append(l2.val)
            l2 = l2.next
        carry = 0
        head = None
        while stack1 or stack2:
            sum = carry
            if stack1:
                sum += stack1.pop()
            if stack2:
                sum += stack2.pop()
            carry, sum = sum//10, sum%10
            head = ListNode(sum, head)
        if carry != 0:
            head = ListNode(1, head)
        return head
    
        
        
        
    
        
l1 = ListNode(7)
l1.next = ListNode(2)
l1.next.next = ListNode(4)
l1.next.next.next = ListNode(3)

l2 = ListNode(5)
l2.next = ListNode(6)
l2.next.next = ListNode(4)

answer = Solution()
print(answer.addTwoNumbers(l1,l2))

# %%
print(7//10, 7%10)
print(17//10, 17%10)
print(27//10, 27%10)

# %%
    def addTwoHugeNumbers(self, a, b):  
        num1 = ''
        n = 0
        while (n < len(a)):
            print(n)
            a_temp = a[n]
            while (a_temp):
                num1 = num1+str(a_temp.value)
                #print(num1)
                a_temp = a_temp.next
            n += 1
        num1 = int(num1)

        num2 = ''
        n = 0
        while (n < len(b)):
            print(n)
            b_temp = b[n]
            while (b_temp):
                num2 = num2+str(b_temp.value)
                #print(num1)
                b_temp = b_temp.next
            n += 1
        num2 = int(num2)
        #print(num1)
        #print(num2)
        num3 = num1+num2
        print(num3)
        num3_str = str(num3)
        answer = []
        n = 0
        while n < len(num3_str):
            m = 0
            while m < 4:
                if (m == 0):
                    head_temp = ListNode(num3_str[n])
                else:
                    head_temp.next = ListNode(num3_str[n+m])
                m = +1
            answer.append(head-temp)
            n = +1
        return answer

# %%
# bloomberg ll questions
class ListNode(object):
    #def __init__(self, x, nxt=None, random=None):
    #def __init__(self, x):
    def __init__(self, x, nxt=None,, prev=None, child=None):
        self.value = x
        self.val = x
        self.next = nxt
        self.prev = prev
        self.child = child
        self.random = random
        
        
class Solution:

# %%
class ListNode(object):
    def __init__(self, x):
        self.value = x
        self.val = x
        self.next = None
        
        
        

    # print the linked list
    def print_list(self):
        #current_node = self.head 
        #current_node = self.value 
        print('printing list')
        current_node = self
        while (current_node): 
            #print (str(current_node.value)+' ->') 
            print (current_node.value) 
            current_node = current_node.next
            
    def removeKFromList(l, k):  
        # remove header values
        while (l is not None and l.value == k):
            l = l.next
        current = l
        while current:
            #print(current.value)
            if (current.next and current.next.value == k):
                current.next = current.next.next
            else:
                current = current.next
        return l  
    
    def hasCycle(self, head):
        slow = head
        fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow == fast:
                return True
        return False

    def detectCycle(self, head):
        slow = head
        fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            #print(slow.value, fast.value)
            if (slow == fast):
                while head != slow:
                    slow = slow.next
                    head = head.next
                    return head
        return None
    
    def getIntersectionNode(self, l1, l2):
        currl1, currl2 = l1, l2
        len1 = len2 = 0
        while currl1:
            len1 += 1
            currl1 = currl1.next
        while currl2:
            len2 += 1
            currl2 = currl2.next
        currl1, currl2 = l1, l2
        if len1 > len2:
            for i in range(len1-len2):
                currl1 = currl1.next
        elif lenl1 =< lenl2:
            for i in range(len2-len1):
                currl2 = currl2.next
        while currl1 != currl2:
            currl1 = currl1.next
            currl2 = currl2.next
        return currl1
        

    def removeNthFromEnd(self, head, n):    
        dummy = ListNode(0)
        dummy.next = head
        fast = slow = dummy
        for i in range(0, n, 1):
            fast = fast.next
        while fast and fast.next:
            fast = fast.next
            slow = slow.next
        slow.next = slow.next.next
        return dummy.next    
    
    def removeElements(self, head, val):
        #if not head:
        #    return None
        #print(head.val)
        #while head.val == val:
        #   if (head.next):
        #       head = head.next
        #    else:
        #        return None
        #current = head
        #while current.next:
        #    if (current.next.val == val):
        #        current.next = current.next.next
        #    else:
        #        current = current.next
        #return head
        [head, head.next] = [ListNode(-9999), head]
        current = head
        while current.next:
            if current.next.val == val:
                current.next = current.next.next
            else: 
                current = current.next
        return head.next

    def oddEvenList(self, head):
        #if not head or not head.next:
        if not head:
            return head
        odd = head
        even = head.next
        evenhead = even
        while even and even.next: 
            odd.next = odd.next.next
            odd = odd.next
            even.next = even.next.next
            even = even.next
        odd.next = evenhead 
        return head     
    
    def isPalindrome(self,head):
        # reach half way point
        slow = fast = head
        while (fast and fast.next):
            slow = slow.next
            fast = fast.next.next
        # reverse 2nd half
        prev = None
        curr = slow
        while curr:
            nex = curr.next
            curr.next = prev
            prev = curr
            curr = nex
        # compare both halves
        while prev:
            if prev.val != head.val:
                return False
            prev = prev.next
            head = head.next
        return True

        
    def mergeTwoLists(self, l1, l2):
        dummy = current = ListNode(0)
        while l1 and l2:
            if l1.val < l2.val:
                current.next = l1
                l1 = l1.next
            else:
                current.next = l2
                l2 = l2.next
            current = current.next
        if l1:
            current.next = l1
        else:
            current.next = l2
        return dummy.next
                
        
    def reverseList(self, head):
        previous = None
        while head:
            current = head
            head = head.next
            current.next = previous
            previous = current
        return current

# %%
# Node class 
class Node:   
    def __init__(self, data): 
        self.data = data  # Assign data 
        self.value = data  # Assign data 
        self.next = None  # Initialize next as null 
        # doubly linked list
        #self.previous = None

# Linked List class contains a Node object 
class LinkedList:   
    # Function to initialize head 
    def __init__(self): 
        self.head = None
        
    # print the linked list
    def print_list(self):
        current_node = self.head 
        while (current_node): 
            print (current_node.data) 
            current_node = current_node.next

    # insert data at beginning 
    def add_data_at_beginning(self,new_data):
        # allocate new_data to a Node class
        new_node = Node(new_data)
        # next value is previous list head 
        new_node.next = self.head
        # head points to new_node
        self.head = new_node        
            
    def add_data_at_end(self, new_data):
        # allocate new_data to a Node class
        new_node = Node(new_data) 
        # if the list is empty, make the new_node the head 
        if self.head is None: 
            self.head = new_node 
            return
        # traverse the full list        
        last = self.head
        while(last.next):
            last = last.next
        # insert new node at the end 
        last.next = new_node
 
    # Function to add node
    def add_data_after_middle_node(self, middle_node, new_data):
        # allocate new_data to a Node class
        new_node = Node(new_data)
        #middle_node = Node(middle_data)
        # check that middle_node exists
        if middle_node is None:
            print("The mentioned node is absent")
            return          
        # next of new_node is next of middle_node 
        new_node.next = middle_node.next
        # next of middle_node is new_node 
        middle_node.next = new_node 
        
    def delete_node(self, data_to_delete):  
        # start at the head 
        current_node = self.head  
        previous_node = None
        found = False
        while (current_node and not found): 
            if (current_node.data == data_to_delete):  
                found = True 
            else:
                previous_node = current_node
                current_node = current_node.next
        # if key was not present in linked list  
        if(current_node == None):
            print('key is not present in linked list')
            return
        if (previous_node is None):
            self.head = current_node.next
        else:
            # Unlink the node from linked list  
            previous_node.next = current_node.next  
            current_node = None
        
    def count_length_of_list(self):            
        current_node = self.head  
        # If head node itself holds the key to be deleted  
        list_length = 0
        while (current_node): 
            current_node = current_node.next
            list_length += 1        
        return list_length
