# %%
class Solution:
    def findMaxConsecutiveOnes(self, nums):
        count = 0
        max_count = 0
        for num in nums:
            if num == 1:
                count += 1
            else:
                maxCount = max(count,max_count)
                count = 0
        return max(count,max_count)

    def findNumbers(self, nums):
        n_nums = len(nums)
        even_count = 0
        for num in nums:
            #print(num)
            #print(len(str(num)))
            if (len(str(num))%2==0):
                even_count += 1
        return even_count
    
    def sortedSquares(self, A):
        from collections import deque
        answer = deque()
        [l, r] = [0, len(A)-1]
        while l <= r:
            left_value, right_value = abs(A[l]), abs(A[r])
            if left_value > right_value:
                answer.appendleft(left_value**2)
                l += 1
            else:
                answer.appendleft(right_value**2)
                r -= 1
        return list(answer)    

    def duplicateZeros(self, arr):    
        [p1, p2] = [0,0]
        while (p1 < len(arr)-1):
            print(p1, len(arr))
            if (arr[p1] == 0):
                arr[p1+2::] = arr[p1+1:-1]
                arr[p1+1] = 0
                print(arr)
                p1 += 2
            else:
                p1 += 1

    def merge(self, nums1, m, nums2, n):
        #total = len(nums1)
        while m > 0 and n > 0:
            if (nums1[m-1] > nums2[n-1]):
                nums1[m+n-1] = nums1[m-1]
                m -= 1
            else:
                nums1[m+n-1] = nums2[n-1]
                n -= 1
        nums1[:n] = nums2[:n]
    
    def checkIfExist(self, arr):
        checker = []
        for num in arr:
            if num in checker:
                return True
            checker.append(num*2)
            #print(num)
            if (num%2 == 0):
                checker.append(num/2)
            print(checker)
        return False

    def validMountainArray(self, A):    
        n_nums = len(A)
        print(n_nums)
        if (n_nums < 3):
            return False
        if (A[1] < A[0]):
            print(A[0])
            print(A[1])
            print('here')
            return False
        previous_sign_change = 'positive'
        for n in range(1, n_nums, 1):
            print(previous_sign_change)
            if (A[n] == A[n-1]):
                return False
            if   (A[n] < A[n-1] and previous_sign_change == 'positive'):
                previous_sign_change = 'negative'
            elif (A[n] > A[n-1] and previous_sign_change == 'negative'):
                return False
        if   (previous_sign_change == 'positive'):
            return False
        return True 
    
    
    
    def replaceElements(self, arr):
        n_nums = len(arr)
        max_val_old = arr[-1]
        for n in range(n_nums-1, -1, -1):
            #print(n)
            [arr[n], max_val_old] = [max_val_old, max(max_val_old, arr[n])]
            
            #max_val_new = max(max_val_old, arr[n])
            #arr[n] = max_val_old
            #max_val_old = max_val_new
            #print (n)
            #print(max_val)
            #print(arr)
        arr[-1] = -1
        return arr  
    
    def moveZeroes(self, nums):
        n2 = 0
        for n1 in range(len(nums)):
            if nums[n1] != 0:
                [nums[n2], nums[n1]] = [nums[n1], nums[n2]]
                n2 += 1
            print(nums)
    
    def sortArrayByParity(self, A):
        [i, j] = [0, len(A)-1]
        while (i < j):
            if (A[i]%2 > A[j]%2):
                [A[i], A[j]] = [A[j], A[i]]
            if A[i] % 2 == 0: 
                i += 1
            if A[j] % 2 == 1: 
                j -= 1
        return A
            
        
    def sortedSquares(self, A):
        n_nums = len(A)
        j = 0
        for i in range(0, n_nums, 1):
            if (A[i] < 0):
                while (A[j] < 0) and (abs(A[i]) < A[j]):
                    j += 1
                    print(A[i], A[j])
                [A[i], A[j]] = [abs(A[j]), A[i]]
            #else:
            #    A[i] = A[i]**2
            print(A)
        
    def heightChecker(self, heights):
        n_nums = len(heights)
        moves = 0
        for n in range(0, n_nums-1, 1):
            j = n+1
            if (heights[j] < heights[n]):
                moves += 1
                while (heights[n] < heights[j]):
                    j = +1
                [heights[n], heights[j]] = [heights[j], heights[n]]                 
            print (n, heights)
        return moves
        
    def thirdMax(self, nums):        
        n_nums = len(nums)
        #print(n_nums)
        dict_nums = {}
        max_list = [-float(inf) ,-float(inf) ,-float(inf)]
        for n in range(0, n_nums, 1):
            if (nums[n] > max_list[0] and nums[n] not in max_list):
                max_list[0] = nums[n]
                max_list = sorted(max_list)
            print(max_list)
            #print(max1, max2, max3)
        if (n_nums == 2):
            return(max_list[1])
        return(max_list[0])

    def findDisappearedNumbers(self, nums):    
        #n_nums = len(nums)
        #dict_nums = {}
        #for n in range(0, n_nums, 1):
        #    if (nums[n] not in dict_nums):
        #        dict_nums[nums[n]] = 1
        #print(dict_nums)
        #not_in_list = []
        #for n in range(1, max(dict_nums), 1):
        #    print (n)
        #    if n not in dict_nums:
        #        not_in_list.append(n)
        #return not_in_list
        n_nums = len(nums)
        n  = 0
        #while
        for n in range(0, n_nums, 1):
        #n_nums = len(nums)
        #for n in range(0, n_nums, 1):
            if (nums[n] != n):
                [nums[nums[n]], nums[n]] = [nums[n], nums[nums_n[n]]]  
            print(nums)
        #return not_in_list
        
    def containsDuplicate(self, nums):
        dict_nums = {}
        n_nums = len(nums)
        for n in range(0, n_nums, 1):
            if (nums[n] in dict_nums):
                return True
            else:
                dict_nums[nums[n]] = 1
                #unique.add(nums[n])
        return False
        #n_nums = len(nums)
        #unique = {nums[0]}
        #for n in range(1, n_nums, 1):
        #    if (nums[n] in unique):
        #        return True
        #    else:
        #        unique.add(nums[n])
        #return False

    def singleNumber(self, nums):
        n_nums = len(nums)
        dict_nums = {}
        for n in range(0, n_nums, 1):
            if nums[n] in dict_nums:
                dict_nums[nums[n]] += 1
            else:
                dict_nums[nums[n]] = 1
        for key in dict_nums:
            #print(key, dict_nums[key])
            if (dict_nums[key] == 1):
                return key
        return False
        #hash_table = {}
        #for num in nums:
        #    print(num)
        #    #hash_table[num] += 1
        #    hash_table[num] = hash_table.get(num, 0)+1            
        #print(hash_table)
        #for i in hash_table:
        #    if hash_table[i] == 1:
        #        return i            

    def intersection(self, nums1, nums2):
        n_nums1 = len(nums1)
        n_nums2 = len(nums2)
        dict_nums1 = {}
        dict_nums2 = {}
        for n in range(0, n_nums1, 1):
            if nums1[n] not in dict_nums1:
                dict_nums1[nums1[n]] = 1
        for n in range(0, n_nums2, 1):
            if nums2[n] not in dict_nums2:
                dict_nums2[nums2[n]] = 1
        dict_intersect = {}
        print(dict_nums1)
        print(dict_nums2)
        for key in dict_nums1:
            if key in dict_intersect:
                dict_intersect[key] += 1
            else:
                dict_intersect[key] = 1
        for key in dict_nums2:
            if key in dict_intersect:
                dict_intersect[key] += 1
            else:
                dict_intersect[key] = 1
        intersect = []
        for key in dict_intersect:
            if (dict_intersect[key] == 2):
                intersect.append(key)
        return intersect

    def isHappy(self, n):    
        max_count = 500
        count = 0
        new_num = n
        while new_num != 0 and count < max_count:
            n_str = str(new_num)
            len_str = len(n_str)
            for n in range(0, len_str, 1):
                if n == 0:
                    new_num = int(n_str[n])**2
                else:
                    new_num = new_num + int(n_str[n])**2
            print(new_num)
            if (new_num == 1):
                return True
            count += 1
        return False
        
    def twoSum(self, nums, target):    
        n_nums = len(nums)
        dict_nums = {}
        for i, n in enumerate(nums):
            print(i,n)
            m = target - n
            if m in dict_nums:
                return [dict_nums[m], i]
            else:
                dict_nums[n] = i                
        
    def intersect(self, nums1, nums2):
        n_nums1 = len(nums1)
        n_nums2 = len(nums2)
        dict_nums1 = {}
        dict_nums2 = {}
        for n in range(0, n_nums1, 1):
            if nums1[n] not in dict_nums1:
                dict_nums1[nums1[n]] = 1
            else:
                dict_nums1[nums1[n]] += 1
        #print(dict_nums1)
        for n in range(0, n_nums2, 1):
            if nums2[n] not in dict_nums2:
                dict_nums2[nums2[n]] = 1
            else:
                dict_nums2[nums2[n]] += 1
        dict_intersect = dict_nums1
        #print(dict_nums1)
        #print(dict_nums2)
        #print (dict_intersect)
        for key in dict_intersect:
            #print(key)
            if key in dict_nums2:
                dict_intersect[key] = min(dict_intersect[key],dict_nums2[key])
            else:
                dict_intersect[key] = 0
            #print (dict_intersect)
        intersect = []
        for key in dict_intersect:
            if (dict_intersect[key] > 0):
                n_times = int(dict_intersect[key])
                #print(n_times)
                for n in range(0, n_times, 1):
                    intersect.append(key)
                #print(intersect)
        return intersect            
        
    def containsNearbyDuplicate(self, nums, k):        
        #dict_index = {}
        #for n in range(0, len(nums), 1):
        #    if nums[n] not in dict_index:
        #        dict_index[nums[n]] = [n]
        #    else:
        #        dict_index[nums[n]].append(n)
        #for key, value in dict_index.items():
        #    if (len(value) >= 2):
        #        index_temp = dict_index[key]
        #        print(index_temp)
        #       min_diff = abs(index_temp[-1] - index_temp[0])
        #        if (min_diff <= k):
        #            return True
        #        else:
        #            for n in range(1, len(index_temp)-1, 1):
        #                min_diff = min(abs(index_temp[n-1] - index_temp[n]), abs(index_temp[n] - index_temp[n+1]))
        #                if (min_diff <= k):
        #                    return True

        dict_index = {}
        for n, num in enumerate (nums):
            print (n, num)
            if num in dict_index and (n-dict_index[num] <= k):
                return True
            dict_index[num] = n
            return False
            
    def numJewelsInStones(self, J, S):
        count = 0
        for n in range(0, len(S), 1):
            print (S[n])
            if S[n] in J:
                count += 1
        return count
    
    def majorityElement(self, nums):
        n_nums = len(nums)
        majority = n_nums//2
        if (n_nums%2 == 1):
            majority += 1
        print (n_nums, majority)
        dict_nums = {}
        for n in range(0, n_nums, 1):
            if nums[n] in dict_nums:
                dict_nums[nums[n]] += 1
            else:
                dict_nums[nums[n]] =  1
            if (dict_nums[nums[n]] >= majority):
                return nums[n]
        
    def moveZeroes(self, nums):
        n_nums = len(nums)        
        i = 0
        for j in range(0, n_nums, 1):
            if nums[j] != 0:
                [nums[i], nums[j]] = [nums[j], nums[i]]
                i += 1            
            #if nums[i] != 0:
            #    i += 1
            print(nums)

    def maxProfit(self, nums):            
        n_nums = len(nums)

        #profit = [0]*n_nums
        #for i in range(0, n_nums, 1):
        #   for j in range(i, n_nums, 1):
        #        profit[i] = max(profit[i], (nums[j] - nums[i]))
        #    print(profit)
        #eturn(max(profit))

        slow = 0
        fast = 1
        max_profit = 0
        for fast in range(1, n_nums, 1):
            print(nums[fast], nums[slow])
            profit = nums[fast] - nums[slow]
            if (profit > max_profit):
                max_profit = profit
            if (nums[fast] < nums[slow]):
                slow = fast            
            print(max_profit)
        return(max_profit)

    def findUnsortedSubarray(self, nums):
        n_nums = len(nums)
        start_index = n_nums
        end_index = 0
        unsorted_length = 0
        print('start')
        for n in range(0, n_nums-1, 1):
            if (nums[n+1] < nums[n]):
                start_index = min(start_index, n)
                print(start_index, end_index)
        print('end')
        for n in range(n_nums-1, 0, -1):
            if (nums[n-1] > nums[n] or nums[n] < nums[start_index]):
                print(nums[n-1], nums[n])
                end_index   = max(  end_index, n)
                print(start_index, end_index)
                unsorted_length = end_index-start_index+1
        return unsorted_length

        if n_nums < 2:
            return 0
        
        prev = nums[0]
        end = 0
        # find the largest index not in place
        for i in range(0, n_nums, 1):
            if nums[i] < prev:
                end = i
            else:
                prev = nums[i]

        start = len(nums) - 1
        prev = nums[start]
        # find the smallest index not in place
        for i in range(len(nums)-1, -1, -1):
            if prev < nums[i]:
                start = i
            else:
                prev = nums[i]
        if end != 0:
            return end - start + 1
        else: 
            return 0    
    
    def fizzBuzz(self, n):
        str_result = []
        #if (n == 1):
        #    str_result.append(str(n))
        #else:
        for n in range(1, n+1, 1):
            if n%3 == 0 and n%5 == 0:
                str_result.append("FizzBuzz")
            elif n%3 == 0:
                str_result.append("Fizz")
            elif n%5 == 0:
                str_result.append("Buzz")
            else:
                str_result.append(str(n))
        return str_result
       
    def missingNumber(self, nums):        
        dict_nums = {}
        n_nums = len(nums)
        print(n_nums)
        for n in range(0, n_nums, 1):
            print(n+1, nums[n])
            if nums[n] not in dict_nums:
                dict_nums[nums[n]] = 1
            else:
                del dict_nums[nums[n]]
                #print(nums[n])
                #print('delete1')
            if n+1 not in dict_nums:
                dict_nums[n+1] = 1
            else:
                del dict_nums[n+1]
                #print(n)
                #print('delete1')

        print(dict_nums)
        for key,value in dict_nums.items():
            print(key, value)
            if key > 0 and key < n_nums+1:
                return key
        return 0
    
    def mySqrt(self, x):
        #n = 0
        #while (n*n < x):
        #    print(n)
        #   n += 1
        #return n-1
        l, r = 0, x
        while l <= r:
            mid = (r+l)/2
            if mid*mid <= x < (mid+1)*(mid+1):
                return mid
            elif mid*mid > x:
                r = mid - 1
            else:
                l = mid + 1        

x = 8
# Output: 2        

#nums = [2, 6, 4, 8, 10, 9, 15]
#nums = [2,6,4,8,10,9,15]
#nums = [1,2,3,4]
#nums = [1,3,2,2,2]
temp1 = Solution()
print(temp1.mySqrt(x))
# Out:
# 0
# 1
# 2
# 2

# %%
nums = [1,2]
[max1, max2] = sorted([nums[0], nums[1]], reverse=True)

print(max1,max2)

# %%
nums2 = [2,5,6]
print(nums2)
nums2.popleft()
print(nums2)

# %%
for n in range(10, -1, -1):
    print(n)

# %%
arr = [0, 1, 2, 3, 4, 5]
print(type(arr))
arr.insert(2,0)
print(arr)
arr.pop()
print(arr)

# %%
abs(-3)
from collections import deque
stack = deque()
stack.append(1)
stack.append(2)        
stack.append(3)        
stack.append(4)
print(stack)
print(stack[-1])
temp1 = stack.pop()
print(stack)

if stack:
    print(stack)
else:
    print('no stack')

# %%
from collections import deque
stack = deque()
stack.append('a')
print(stack)
stack.append('b')
stack.append('c')
print(stack)
stack.pop()
print(stack)

# %%
print(2%2)
print(3%2)
print(4%2)

# %%
def isCryptSolution(crypt, solution):
    len_solution = len(solution)
    zero_char = None
    for n in range(0, len_solution, 1):
        if (solution[n][1] == "0"):
            print(solution[n][0])
            zero_char = solution[n][0]
            
    if zero_char:
        n_words = len(crypt)
        for n in range(0, n_words, 1):
            n_letters = len(crypt[n])
            if n_letters > 1:
                #if crypt[n].startswith(zero_char):
                if crypt[n][0] == zero_char:
                    return False
    
    return True


crypt_s = crypt
    for i in range(0, 3):
        for s in solution:
            crypt_s[i] = crypt_s[i].replace(s[0], s[1])
        
        if crypt_s[i] != '0' and crypt_s[i][0] == '0':
            return False
        
    if int(crypt_s[0]) + int(crypt_s[1]) != int(crypt_s[2]):
        return False
    
    return True


crypt = ["SEND", "MORE", "MONEY"]
#print(len(crypt[0]))


solution = [["O","0"], 
 ["M","1"], 
 ["Y","2"], 
 ["E","5"], 
 ["N","6"], 
 ["D","7"], 
 ["R","8"], 
 ["S","9"]]

#print(len(solution))
len_solution = len(solution)
for n in range(0, len_solution, 1):
    if (solution[n][1] == "0"):
        print(solution[n][0])

#print(solution[0])

# %%
grid = [[".",".",".","1","4",".",".","2","."], 
 [".",".","6",".",".",".",".",".","."], 
 [".",".",".",".",".",".",".",".","."], 
 [".",".","1",".",".",".",".",".","."], 
 [".","6","7",".",".",".",".",".","9"], 
 [".",".",".",".",".",".","8","1","."], 
 [".","3",".",".",".",".",".",".","6"], 
 [".",".",".",".",".","7",".",".","."], 
 [".",".",".","5",".",".",".","7","."]]

print(grid)
#print(grid[4][4])

for i in range(0, 9, 1):
    dict_temp = {}
    for j in range(0, 9, 1):
        if grid[j][i] in dict_temp:
            print(grid[j][i], dict_temp)
            #return False
        else:
            dict_temp[grid[j][i]] = 1
for j in range(0, 9, 1):
    dict_temp = {}
    for i in range(0, 9, 1):
        if grid[j][i] in dict_temp:
            print(False)
            #return False
        else:
            dict_temp[grid[j][i]] = 1
for m in range(0, 3, 1):
    for n in range(0, 3, 1):
        print(m,n)
        dict_temp = {}        
        for i in range(3*m, 3*m+3, 1):
            for j in range(3*n, 3*n+3, 1):
                if grid[j][i] in dict_temp:
                    print(False)
                    #return False
                else:
                    dict_temp[grid[j][i]] = 1

# %%
class Solution:
        
    def topKFrequent(self, nums, k):    
        n_nums = len(nums)
        dict_nums = {}
        for n in range(0, n_nums, 1):
            if nums[n] in dict_nums:
                dict_nums[nums[n]] += 1 
            else:
                dict_nums[nums[n]] = 1 
            #print(n)
        sorted_dict_nums = sorted(dict_nums.items(), key=lambda x: x[1], reverse=True)
        most_common = []
        for i in range(0, k, 1):
            most_common.append(sorted_dict_nums[i][0])
        return most_common
    
    def maxSubArray(self, nums):
        print(nums)
        for i in range(1, len(nums)):
            #print('i, prev nums %s %s' %(i, nums[i-1]))
            if (nums[i-1] > 0):
                nums[i] += nums[i-1]
                print(nums)
        return max(nums)

    def findRadius(self, houses, heaters):    
        #n_houses = len(houses)
        #n_heaters = len(heaters)
        ##print(n_houses)
        #max_diff = 0
        #i = 0
        #n = 0
        #for n in range(0, n_houses, 1):
        #    if (i < (n_heaters-1)):
        #        if (houses[n] > heaters[i+1]):
        #            print('move to the next heater')
        #            i += 1
        #    diff_left = abs(houses[n] - heaters[i])
        #    if (i < (n_heaters-1)):
        #        diff_right = abs(houses[n] - heaters[i+1])
        #        max_diff = max(max_diff, min(diff_left, diff_right))
        #    else:
        #        max_diff = max(max_diff, diff_left)
        #    #print(n, i, diff_left, diff_right)
        #    #print(houses[n], heaters[i])
        #    #print([heaters])
        #    print(max_diff)
        #return max_diff
        
        n_houses  = len(houses)
        n_heaters = len(heaters)
        #print(n_houses)
        max_diff = abs(houses[0] - heaters[0])
        n = 0
        m = 0
        min_diff = []
        for n in range(0, n_houses, 1):
            min_diff_temp = abs(houses[n] - heaters[0])
            for m in range(0, n_heaters, 1):
                diff_temp = abs(houses[n] - heaters[m])
                #print(n, m, max_diff)
                min_diff_temp = min(min_diff_temp, diff_temp)
            min_diff.append(min_diff_temp)
            print(min_diff)
        return max(min_diff)

    def minSubArrayLen(self, s, nums):  
        n_sums = len(nums)
        #print(n_sums)
        length = n_sums+1
        for n in range(0, n_sums, 1):
            print('  n is %s ' %(n))
            temp_sum = 0
            length_temp = n_sums+1
            for m in range(n, n_sums, 1):
                print('    m is %s ' %(m))
                temp_sum = temp_sum + nums[m]
                if (temp_sum >= s):
                    length_temp = min(length_temp, m-n+1)
                    print ('  found length_temp %s ' %(length_temp))
            length = min(length, length_temp)        
            print ('  length is %s ' %(length))
        if (length > n_sums):
            length = 0
        return length
        
    def runningSum(self, nums):
        n_nums = len(nums)
        sum_array = []
        for n in range(0, n_nums, 1):
            if (n == 0):
                sum_array.append(nums[0])
            else:
                sum_array.append(sum_array[n-1]+nums[n])
        #sum_array = [4,6]
        return sum_array

    
    def plusOne(self, digits):
        digits_new = digits
        n_digits = len(digits)
        print (n_digits)
        while (digits[n] == 9)
        if (n_digits == 1):            
            if (digits_new[-1] == 9):
                digits_new[-1] = 1
                digits_new.append(0)
            else:    
                digits_new[-1] = digits_new[-1]+1
        else: 
            digits_new[-1] = digits_new[-1]+1
            
        return digits_new

# %%
digits = [1,2,3,4]
digits = [9,9]
#digits = [9]
temp1 = Solution()
print(temp1.plusOne(digits))

# %%
temp1 = Solution()

n = 12

print(temp1.numSquares(n))

#Input: n = 12
#Output: 3 
#Explanation: 12 = 4 + 4 + 4.

#Input: n = 12
#Output: 3 
#Explanation: 12 = 4 + 4 + 4.

#Input: n = 13
#Output: 2
#Explanation: 13 = 4 + 9.

#s = 7
#nums = [2,3,1,2,4,3]
#s = 11
#nums = [1,2,3,4,5]
#s = 3
#nums = [1,1]
#s = 15
#nums = [1,2,3,4,5]

#temp1 = Solution()
#print(temp1.minSubArrayLen(s, nums))

# %%
s = 7
nums = [2,3,1,2,4,3]
n_sums = len(nums)
#print(n_sums)
length = n_sums
for n in range(0, n_sums, 1):
    print('  n is %s ' %(n))
    temp_sum = 0
    length_temp = n_sums
    for m in range(n, n_sums, 1):
        print('    m is %s ' %(m))
        temp_sum = temp_sum + nums[m]
        if (temp_sum > s):
            length_temp = m-n
            length = min(length_temp, m-n)
print(length)
#Output: 2
# Explanation: the subarray [4,3] has the minimal length under the problem constraint.

# %%
Input: s = 7, nums = [2,3,1,2,4,3]
Output: 2
Explanation: the subarray [4,3] has the minimal length under the problem constraint.

#houses = [1,2,3]
#heaters = [2]
#houses =  [1,2,3,4]
#heaters = [1,4]

houses =  [282475249,622650073,984943658,144108930,470211272,101027544,457850878,458777923]
heaters = [823564440,115438165,784484492,74243042,114807987,137522503,441282327,16531729,823378840,143542612]
temp1 = Solution()
print(temp1.findRadius(houses,heaters))

# %%
houses = [2, 4, 6, 8]
heaters = [5, 3, 7]
heaters - 2

# %%
#nums1 = [1,2,2,1]
#nums2 = [2,2]
nums1 = [4,9,5]
nums2 = [9,4,9,8,4]

answer = Solution()
print(answer.intersection(nums1,nums2))
#print(inter)
#print(n1, n2)
#print(2 in nums1)

#Output: [2]
#Example 2:
#Output: [9,4]

# %%
nums2 = [9,4,9,8,4]
nums1 = [4,9,5]
nums2 = [9,4,9,8,4]
set_nums1 = set(nums1)
set_nums2 = set(nums2)
#set_nums1 = list(set(nums1))
#set_nums2 = list(set(nums2))
print(set_nums1[0] in set_nums2)
print(set_nums1)
print(set_nums2)
#print(len(nums2))
#print(nums2[1])

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]

answer = Solution()
print(answer.maxSubArray(nums))
#Output: 6
#Explanation: [4,-1,2,1] has the largest sum = 6.

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]
answer = Solution()
print(answer.maxSubArray(nums))

# %%
print(sorted_dict_nums[0])
print(sorted_dict_nums[0][0])
print(sorted_dict_nums[0][1])

# %%
dict_nums = {1:3, 2:2, 3:1}
print(dict_nums)

# %%
nums = [2, 7, 11, 15]

target = 9

# return [0, 1].

answer = Solution()
print(answer.twoSum(nums, target))
#print(answer.singleNumber(nums))

# %%
hash_table = {}
hash_table[1] = 2
print(hash_table)

# %%
answer = Solution()
answer.containsDuplicate(nums)

# %%
temp1 = {0}
print(temp1)
print(type(temp1))
temp1.add(2)
temp1.add(3)
print(temp1)
temp1.remove(2)
print(temp1)

#print(1 in temp1)
#print(2 in temp1)

# %%
nums = [1, 2, 3]
k = 2
print(len(nums))
print(k%len(nums))

# %%
sample_string = 'hello'

# %%
print (len(sample_string))
len_str = len(sample_string)

# %%
for n in range(0, round(len_str/2)+1, 1):
    #print(sample_string[n])
    temp1 = sample_string[n]
    temp2 = sample_string[len_str-n-1]
    print(n, temp1, temp2)
    sample_string[n] = temp2
    sample_string[len_str-n-1] = temp1

# %%
rev_string = ''
for n in range(0, len_str, 1):
    rev_string = rev_string+sample_string[len_str-n-1]
    print(n, rev_string)

# %%
print(int(5/2))
round(int(5/2))

# %%
sample_string[4] = 'e'

# %%
list(string)

# %%
input_int = 123
temp1 = Solution()
print(temp1.reverse(input_int))

# %%
print([1,-1][0 < 0])

# %%
class Solution(object):
    def firstUniqChar(self, s):   
        d = {}
        for letter in s:
            if letter not in d: 
                d[letter] = 1
            else: 
                d[letter] += 1
        
        index = -1    
        for i in range(len(s)):
            if d[s[i]] == 1:
                return i 
        return -1

# %%
s = "leetcode"
#return 0.
temp1 = Solution()
print(temp1.firstUniqChar(s))

#s = "loveleetcode",
#return 2.

# %%
l = [0,1]
print(len(l))
